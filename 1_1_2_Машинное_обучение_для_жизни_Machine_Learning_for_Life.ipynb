# %% [markdown]
# <a href="https://colab.research.google.com/github/TatyanaLanceva/Netology/blob/main/1_1_2_%D0%9C%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%B5_%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B4%D0%BB%D1%8F_%D0%B6%D0%B8%D0%B7%D0%BD%D0%B8_Machine_Learning_for_Life.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Постройте прогноз своих трат на месяц вперёд по выбранной вами категории.
# Для этого:
#
# - Сформируйте в Google Таблицах датасет (таблицу) на отдельном листе следующего вида:
# |траты в позапрошлом месяце | траты в прошлом месяце | траты в текущем месяце | траты в следующем месяце|
# То есть в таблице должно быть 4 столбца. Внесите данные, чтобы в этой таблице было минимум 8 строчек.
# - Выполните обработку данных (при необходимости);
# - Разделите данные на части — 1 для обучения и 2 для проверки;
# - Сделайте модель линейной регрессии;
# - Оцените качество модели на отложенных данных.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Загружаем данные

# %%
df = pd.read_csv("expense.csv", sep=",")

# %%
df.head()
# Out:
#   Spending category  August  September  October  November
# 0          Mortgage   17350      17350    17350     17350
# 1              Food   15066      45877    24333      4000
# 2           Clothes   14000          0    37444      5464
# 3             Books    3400       1200      345       243
# 4         Utilities    9484      10454     8744      8977

# %% [markdown]
# Смотрим статистику, что нет пропусков и отсутствующих значений

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Spending category  9 non-null      object
#  1   August             9 non-null      int64
#  2   September          9 non-null      int64
#  3   October            9 non-null      int64
#  4   November           9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes

# %%
df.describe()
# Out:
#              August     September       October      November
# count      9.000000      9.000000      9.000000      9.000000
# mean    8447.222222  11553.777778  13651.000000   7974.222222
# std     6141.724163  14127.774956  11320.875706   8376.166706
# min      857.000000      0.000000    345.000000    243.000000
# 25%     3400.000000   1200.000000   7000.000000   1200.000000
# 50%     9484.000000   9706.000000   9099.000000   5464.000000
# 75%    14000.000000  12000.000000  17350.000000   8977.000000
# max    17350.000000  45877.000000  37444.000000  25000.000000

# %% [markdown]
# Формируем признаки и целевую переменную

# %%
df.columns
# Out:
# Index(['Spending category', 'August', 'September', 'October', 'November'], dtype='object')

# %%
X = df[['August', 'September', 'October']]
y = df[['November']]

# %%
X
# Out:
#    August  September  October
# 0   17350      17350    17350
# 1   15066      45877    24333
# 2   14000          0    37444
# 3    3400       1200      345
# 4    9484      10454     8744
# 5    3435       6540     5600
# 6     857       9706    12944
# 7    2433        857     9099
# 8   10000      12000     7000

# %%
y
# Out:
#    November
# 0     17350
# 1      4000
# 2      5464
# 3       243
# 4      8977
# 5      1200
# 6     25000
# 7       634
# 8      8900

# %% [markdown]
# Разделяем данные на выборку для обучения/проверки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#    August  September  October
# 0   17350      17350    17350
# 6     857       9706    12944
# 1   15066      45877    24333
# 4    9484      10454     8744
# 2   14000          0    37444
# 3    3400       1200      345
# 8   10000      12000     7000

# %%
X_test
# Out:
#    August  September  October
# 5    3435       6540     5600
# 7    2433        857     9099

# %%
y_train
# Out:
#    November
# 0     17350
# 6     25000
# 1      4000
# 4      8977
# 2      5464
# 3       243
# 8      8900

# %%
y_test
# Out:
#    November
# 5      1200
# 7       634

# %% [markdown]
# Создаем и обучаем модель линейной регресии

# %%
# Создайте и обучите модель
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[-0.50219981,  0.04463781,  0.12414079]])

# %% [markdown]
# Получаем предсказание и оцениваем качество

# %%
# Получите предсказание
lr.predict(X_test)
# Out:
# array([[11751.82505876],
#        [12435.72123194]])

# %%
# Оценим качество при помощи метода mean_squared_error для тестовой выборки
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, lr.predict(X_test))
# Out:
# 125310818.05350286

# %%
mean_squared_error(y_train, lr.predict(X_train))
# Out:
# 57544974.00316799

# %% [markdown]
# Оценить качество модели на отложенных данных

# %%
lr.predict(X_test)
# Out:
# array([[11751.82505876],
#        [12435.72123194]])
