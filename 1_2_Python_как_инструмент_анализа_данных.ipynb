# %% [markdown]
# <a href="https://colab.research.google.com/github/TatyanaLanceva/Netology/blob/main/1_2_Python_%D0%BA%D0%B0%D0%BA_%D0%B8%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BC%D0%B5%D0%BD%D1%82_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("accounting.csv", sep=",")

# %%
df.describe()

# %%
df.columns
# Out:
# Index(['Отметка времени', 'Месяц операции', 'Название операции',
#        'Сумма операции', 'Категория'],
#       dtype='object')

# %%
df_small=df[['Категория', 'Сумма операции' ]]

# %%
df_small.head ()
# Out:
#   Категория  Сумма операции
# 0       Еда            55.0
# 1       Еда            22.0
# 2   Ипотека         12345.0
# 3   Ипотека         12345.0
# 4   Ипотека         12345.0

# %%
df_small.groupby('Категория').mean()
# Out:
#                      Сумма операции
# Категория
# Еда                      169.714286
# Животные                 566.461538
# Ипотека                12345.000000
# Коммунальные услуги     5273.500000
# Кредит                   948.400000
# Лечение                15454.285714
# Обучение               11384.333333
# Одежда и обувь          1840.833333

# %%
df_small.groupby('Категория').count()
# Out:
#                      Сумма операции
# Категория
# Еда                              14
# Животные                         13
# Ипотека                          12
# Коммунальные услуги               6
# Кредит                           10
# Лечение                           7
# Обучение                          6
# Одежда и обувь                   12
